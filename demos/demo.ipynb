# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
WORKING_DIR = os.path.dirname(os.path.abspath(''))
sys.path.insert(1, os.path.join(WORKING_DIR,'LensQuEst'))

# %%
import universe
from universe import *

import halo_fit
from halo_fit import *

import weight
from weight import *

import pn_2d
from pn_2d import *

import cmb
from cmb import *

import flat_map
from flat_map import *

# %%
print("Map properties")

# number of pixels for the flat map
nX = 400 #1200
nY = 400 #1200

# map dimensions in degrees
sizeX = 10.
sizeY = 10.

# basic map object
baseMap = FlatMap(nX=nX, nY=nY, sizeX=sizeX*np.pi/180., sizeY=sizeY*np.pi/180.)

# multipoles to include in the lensing reconstruction
lMin = 30.; lMax = 3.5e3

# ell bins for power spectra
nBins = 21  # number of bins
lRange = (1., 2.*lMax)  # range for power spectra
# Out:
# Map properties

# %%
print("CMB experiment properties")

# Adjust the lMin and lMax to the assumptions of the analysis
# CMB S3 specs
cmb = StageIVCMB(beam=1., noise=1., lMin=lMin, lMaxT=lMax, lMaxP=lMax, atm=False)

# Total power spectrum, for the lens reconstruction
forCtotal = lambda l: cmb.flensedTT(l) + cmb.fdetectorNoise(l)
#
# reinterpolate: gain factor 10 in speed
L = np.logspace(np.log10(lMin/2.), np.log10(2.*lMax), 1001, 10.)
F = np.array(list(map(forCtotal, L)))
cmb.fCtotal = interp1d(L, F, kind='linear', bounds_error=False, fill_value=0.)
# Out:
# CMB experiment properties

# %%
print("CMB lensing power spectrum")
#generate universe based on plank parameters?
u = UnivPlanck15()

#halofit?
halofit = Halofit(u, save=False)
w_cmblens = WeightLensSingle(u, z_source=1100., name="cmblens")
p2d_cmblens = P2dAuto(u, halofit, w_cmblens, save=False)
# Out:
# CMB lensing power spectrum

# %%
print("Compute the statistical uncertainty on the reconstructed lensing convergence")

print("- standard quadratic estimator")
fNqCmb_fft = baseMap.forecastN0Kappa(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, test=False)
print("- magnification estimator")
fNdCmb_fft = baseMap.forecastN0KappaDilation(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, corr=True, test=False)
print("- shear E-mode estimator")
fNsCmb_fft = baseMap.forecastN0KappaShear(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, corr=True, test=False)
#print "- shear B-mode estimator"
#fNsBCmb_fft = baseMap.forecastN0KappaShearB(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, corr=True, test=False)
#print "- shear E x magnification"
#fNsdCmb_fft = baseMap.forecastN0KappaShearDilation(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMaxS=lMax, lMaxD=lMax, corr=True, test=False)
#print "- shear E x shear B. Not yet working."
#fNssBCmb_fft = baseMap.forecastN0KappaShearShearB(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, corr=True, test=False)
# Out:
# Compute the statistical uncertainty on the reconstructed lensing convergence
# - standard quadratic estimator
# computing the reconstruction noise
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:1737: RuntimeWarning: divide by zero encountered in divide
#   resultFourier = 1./resultFourier
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:1737: RuntimeWarning: invalid value encountered in divide
#   resultFourier = 1./resultFourier
# - magnification estimator
# computing the reconstruction noise
# doing full calculation: computeQuadEstPhiDilationNormalizationCorrectedFFT
# /home/users/delon/LensQuEst/LensQuEst/cmb.py:32: RuntimeWarning: divide by zero encountered in scalar divide
#   self.fdl_to_cl = lambda l: 1./( l*(l+1.)/(2.*np.pi) )
# /home/users/delon/LensQuEst/LensQuEst/cmb.py:42: RuntimeWarning: invalid value encountered in scalar multiply
#   self.funlensedTT = lambda l: (l>=lmin_unlensedCMB and l<=lmax_unlensedCMB) * self.funlensedTT_template(l) * self.fdl_to_cl(l)
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2768: RuntimeWarning: invalid value encountered in divide
#   term1XFourier *= 2. * self.lx / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2772: RuntimeWarning: invalid value encountered in divide
#   term1YFourier *= 2. * self.ly / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2789: RuntimeWarning: invalid value encountered in divide
#   term2XFourier *= 2. * self.lx / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2794: RuntimeWarning: invalid value encountered in divide
#   term2YFourier *= 2. * self.ly / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2807: RuntimeWarning: invalid value encountered in divide
#   resultFourier = 1. / (term1Fourier + term2Fourier)
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3467: RuntimeWarning: invalid value encountered in divide
#   fx = (self.lx**2-self.ly**2) / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3470: RuntimeWarning: invalid value encountered in divide
#   fy = self.lx*self.ly / self.l**2
# - shear E-mode estimator
# computing the reconstruction noise
# doing full calculation: computeQuadEstPhiShearNormalizationCorrectedFFT
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3292: RuntimeWarning: invalid value encountered in divide
#   cosXFourier = shearFourier * (self.lx**2 - self.ly**2) / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3296: RuntimeWarning: invalid value encountered in divide
#   cosYFourier = shearFourier * self.lx * self.ly / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3317: RuntimeWarning: invalid value encountered in divide
#   grad1XcosXFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3322: RuntimeWarning: invalid value encountered in divide
#   grad1YcosXFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3327: RuntimeWarning: invalid value encountered in divide
#   grad1XcosYFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3332: RuntimeWarning: invalid value encountered in divide
#   grad1YcosYFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3350: RuntimeWarning: invalid value encountered in divide
#   grad2XcosXFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3356: RuntimeWarning: invalid value encountered in divide
#   grad2YcosXFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3362: RuntimeWarning: invalid value encountered in divide
#   grad2XcosYFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3368: RuntimeWarning: invalid value encountered in divide
#   grad2YcosYFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3383: RuntimeWarning: invalid value encountered in divide
#   resultFourier = 1. / (term1Fourier + term2Fourier)

# %%
# colors for plots
cQ = 'r'
cS = 'b'
cD = 'g'

# %%
print("Plot noise power spectra")

fig=plt.figure(0)
ax=fig.add_subplot(111)
#
ax.loglog(L, p2d_cmblens.fPinterp(L), 'k-', lw=3, label=r'signal')
#
Nq = fNqCmb_fft(L)
Ns = fNsCmb_fft(L)
Nd = fNdCmb_fft(L)
#Nsd = fNsdCmb_fft(L)
#NsB = fNsBCmb_fft(L)
#NssB = fNssBCmb_fft(L)
#
ax.loglog(L, Ns, c=cS, label=r'shear')
ax.loglog(L, Nd, c=cD, label=r'dilation')
ax.loglog(L, Nq, c=cQ, lw=3, label=r'QE')
#ax.loglog(L, NsB, c='y', label=r'shear B')a
#x.loglog(L, Nsd, c='c', ls='--', label=r'shear$\times$dilation')
#ax.loglog(L, 1./(1./Nd + 1./Ns), c=cQ, ls='-.', label=r'naive shear + dilation')
#ax.loglog(L, (Ns*Nd-Nsd**2)/(Ns+Nd-2.*Nsd), c=cQ, ls='--', lw=3, label=r'shear + dilation')
#ax.loglog(L, NssB, c='y', ls='-.', label=r'shear$\times$shear B')
#
ax.legend(loc=2, fontsize='x-small', labelspacing=0.1)
ax.set_xlabel(r'$L$')
ax.set_ylabel(r'$C_L^\kappa$')

plt.show()
# Out:
# Plot noise power spectra

# %%
print("Generate GRF unlensed CMB map (debeamed)")

cmb0Fourier = baseMap.genGRF(cmb.funlensedTT, test=False)
cmb0 = baseMap.inverseFourier(cmb0Fourier)
print("plot unlensed CMB map")
baseMap.plot(cmb0)
print("check the power spectrum")
lCen, Cl, sCl = baseMap.powerSpectrum(cmb0Fourier, theory=[cmb.funlensedTT], plot=True, save=False)
# Out:
# Generate GRF unlensed CMB map (debeamed)
# /home/users/delon/LensQuEst/LensQuEst/cmb.py:32: RuntimeWarning: divide by zero encountered in scalar divide
#   self.fdl_to_cl = lambda l: 1./( l*(l+1.)/(2.*np.pi) )
# /home/users/delon/LensQuEst/LensQuEst/cmb.py:42: RuntimeWarning: invalid value encountered in scalar multiply
#   self.funlensedTT = lambda l: (l>=lmin_unlensedCMB and l<=lmax_unlensedCMB) * self.funlensedTT_template(l) * self.fdl_to_cl(l)
# plot unlensed CMB map
# check the power spectrum
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:459: RuntimeWarning: invalid value encountered in divide
#   sCl /= np.sqrt(Nmodes)

# %%
print("Generate GRF kappa map")

kCmbFourier = baseMap.genGRF(p2d_cmblens.fPinterp, test=False)
kCmb = baseMap.inverseFourier(kCmbFourier)
print("plot kappa map")
baseMap.plot(kCmb)
print("check the power spectrum")
lCen, Cl, sCl = baseMap.powerSpectrum(kCmbFourier, theory=[p2d_cmblens.fPinterp], plot=True, save=False)
# Out:
# Generate GRF kappa map
# plot kappa map
# check the power spectrum

# %%
print("Lens the CMB map")

lensedCmb = baseMap.doLensing(cmb0, kappaFourier=kCmbFourier)
lensedCmbFourier = baseMap.fourier(lensedCmb)
print("plot lensed CMB map")
baseMap.plot(lensedCmb, save=False)
print("check the power spectrum")
lCen, Cl, sCl = baseMap.powerSpectrum(lensedCmbFourier, theory=[cmb.funlensedTT, cmb.flensedTT], plot=True, save=False)
# Out:
# Lens the CMB map
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:1261: RuntimeWarning: invalid value encountered in divide
#   dxFourier = -2.j * self.lx/self.l**2 * kappaFourier
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:1262: RuntimeWarning: invalid value encountered in divide
#   dyFourier = -2.j * self.ly/self.l**2 * kappaFourier
# plot lensed CMB map
# check the power spectrum

# %%
print("Add white detector noise (debeamed)")

noiseFourier = baseMap.genGRF(cmb.fdetectorNoise, test=False)
totalCmbFourier = lensedCmbFourier + noiseFourier
totalCmb = baseMap.inverseFourier(totalCmbFourier)
baseMap.plot(totalCmb)
print("check the power spectrum")
lCen, Cl, sCl = baseMap.powerSpectrum(totalCmbFourier,theory=[cmb.funlensedTT, cmb.flensedTT, cmb.fCtotal], plot=True, save=False)
# Out:
# Add white detector noise (debeamed)
# check the power spectrum

# %%
print("Reconstructing kappa: standard quadratic estimator")

pathQCmb = "../data/output/qCmb.txt"
baseMap.computeQuadEstKappaNorm(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, 
                                dataFourier=totalCmbFourier, test=False, path=pathQCmb)
qCmbFourier = baseMap.loadDataFourier(pathQCmb)


print("Auto-power: kappa_rec")
lCen, Cl, sCl = baseMap.powerSpectrum(qCmbFourier,theory=[p2d_cmblens.fPinterp, fNqCmb_fft], plot=True, save=False)

print("Cross-power: kappa_rec x kappa_true")
lCen, Cl, sCl = baseMap.crossPowerSpectrum(qCmbFourier, kCmbFourier, theory=[p2d_cmblens.fPinterp, fNqCmb_fft], plot=True, save=False)
# Out:
# Reconstructing kappa: standard quadratic estimator
# saving Fourier map to ../data/output/qCmb.txt
# reading fourier map from ../data/output/qCmb.txt
# Auto-power: kappa_rec
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:459: RuntimeWarning: invalid value encountered in divide
#   sCl /= np.sqrt(Nmodes)
# Cross-power: kappa_rec x kappa_true

# %%
pathQCmb = "../data/output/qCmb.txt"

print("Reconstructing kappa: improved quadratic estimator without noise bias")
baseMap.computeQuadEstPhiInverseDataNormalizationFFT(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, dataFourier=totalCmbFourier, test=False)
qCmbFourier = baseMap.loadDataFourier(pathQCmb)


print("Auto-power: kappa_rec")
lCen, Cl, sCl = baseMap.powerSpectrum(qCmbFourier,theory=[p2d_cmblens.fPinterp, fNqCmb_fft], plot=True, save=False)

print("Cross-power: kappa_rec x kappa_true")
lCen, Cl, sCl = baseMap.crossPowerSpectrum(qCmbFourier, kCmbFourier, theory=[p2d_cmblens.fPinterp, fNqCmb_fft], plot=True, save=False)
# Out:
# Reconstructing kappa: improved quadratic estimator without noise bias
# reading fourier map from ../data/output/qCmb.txt
# Auto-power: kappa_rec
# Cross-power: kappa_rec x kappa_true

# %%
print("Reconstructing kappa: shear estimator")

pathSCmb = "../data/output/sCmb.txt"
baseMap.computeQuadEstKappaShearNormCorr(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, dataFourier=totalCmbFourier, test=False, path=pathSCmb)
sCmbFourier = baseMap.loadDataFourier(pathSCmb)
# Out:
# Reconstructing kappa: shear estimator
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3192: RuntimeWarning: divide by zero encountered in divide
#   resultFourier *= -2. / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3192: RuntimeWarning: invalid value encountered in multiply
#   resultFourier *= -2. / self.l**2
# doing full calculation: computeQuadEstPhiShearNormalizationCorrectedFFT
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3292: RuntimeWarning: invalid value encountered in divide
#   cosXFourier = shearFourier * (self.lx**2 - self.ly**2) / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3296: RuntimeWarning: invalid value encountered in divide
#   cosYFourier = shearFourier * self.lx * self.ly / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/cmb.py:32: RuntimeWarning: divide by zero encountered in scalar divide
#   self.fdl_to_cl = lambda l: 1./( l*(l+1.)/(2.*np.pi) )
# /home/users/delon/LensQuEst/LensQuEst/cmb.py:42: RuntimeWarning: invalid value encountered in scalar multiply
#   self.funlensedTT = lambda l: (l>=lmin_unlensedCMB and l<=lmax_unlensedCMB) * self.funlensedTT_template(l) * self.fdl_to_cl(l)
# saving Fourier map to ../data/output/sCmb.txt
# reading fourier map from ../data/output/sCmb.txt
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3317: RuntimeWarning: invalid value encountered in divide
#   grad1XcosXFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3322: RuntimeWarning: invalid value encountered in divide
#   grad1YcosXFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3327: RuntimeWarning: invalid value encountered in divide
#   grad1XcosYFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3332: RuntimeWarning: invalid value encountered in divide
#   grad1YcosYFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3350: RuntimeWarning: invalid value encountered in divide
#   grad2XcosXFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3356: RuntimeWarning: invalid value encountered in divide
#   grad2YcosXFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3362: RuntimeWarning: invalid value encountered in divide
#   grad2XcosYFourier *= 2. * self.lx / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3368: RuntimeWarning: invalid value encountered in divide
#   grad2YcosYFourier *= 2. * self.ly / 1.j / self.l**4 # for grad
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:3383: RuntimeWarning: invalid value encountered in divide
#   resultFourier = 1. / (term1Fourier + term2Fourier)

# %%
print("Auto-power: kappa_rec")
lCen, Cl, sCl = baseMap.powerSpectrum(sCmbFourier,theory=[p2d_cmblens.fPinterp, fNsCmb_fft], plot=True, save=False)
# Out:
# Auto-power: kappa_rec

# %%
print("Cross-power: kappa_rec x kappa_true")
lCen, Cl, sCl = baseMap.crossPowerSpectrum(sCmbFourier, kCmbFourier, theory=[p2d_cmblens.fPinterp, fNsCmb_fft], plot=True, save=False)
# Out:
# Cross-power: kappa_rec x kappa_true

# %%
print("Reconstructing kappa: magnification estimator")

pathDCmb = "../data/output/dCmb.txt"
baseMap.computeQuadEstKappaDilationNormCorr(cmb.funlensedTT, cmb.fCtotal, lMin=lMin, lMax=lMax, dataFourier=totalCmbFourier, test=False, path=pathDCmb)
dCmbFourier = baseMap.loadDataFourier(pathDCmb)
# Out:
# Reconstructing kappa: magnification estimator
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2646: RuntimeWarning: divide by zero encountered in divide
#   productFourier *= - 2. / self.l**2
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2646: RuntimeWarning: invalid value encountered in multiply
#   productFourier *= - 2. / self.l**2
# doing full calculation: computeQuadEstPhiDilationNormalizationCorrectedFFT
# saving Fourier map to ../data/output/dCmb.txt
# reading fourier map from ../data/output/dCmb.txt
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2768: RuntimeWarning: invalid value encountered in divide
#   term1XFourier *= 2. * self.lx / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2772: RuntimeWarning: invalid value encountered in divide
#   term1YFourier *= 2. * self.ly / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2789: RuntimeWarning: invalid value encountered in divide
#   term2XFourier *= 2. * self.lx / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2794: RuntimeWarning: invalid value encountered in divide
#   term2YFourier *= 2. * self.ly / self.l**2 / 1.j # factor of i to cancel the one in the gradient
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2807: RuntimeWarning: invalid value encountered in divide
#   resultFourier = 1. / (term1Fourier + term2Fourier)

# %%
print("Auto-power: kappa_rec")
lCen, Cl, sCl = baseMap.powerSpectrum(dCmbFourier,theory=[p2d_cmblens.fPinterp, fNdCmb_fft], plot=True, save=False)
# Out:
# Auto-power: kappa_rec

# %%
print("Cross-power: kappa_rec x kappa_true")
lCen, Cl, sCl = baseMap.crossPowerSpectrum(dCmbFourier, kCmbFourier, theory=[p2d_cmblens.fPinterp, fNdCmb_fft], plot=True, save=False)
# Out:
# Cross-power: kappa_rec x kappa_true

# %% [markdown]
# # For "Auto from cross: CMB lensing power spectrum without noise bias" [24XX.XXXXX](https://arxiv.org/abs/24XX.XXXXX)

# %%
plt.rcParams['text.usetex'] = True

# compute QE
QE = baseMap.computeQuadEstKappaNorm(cmb.funlensedTT, 
                                     cmb.fCtotal, 
                                     lMin=lMin, lMax=lMax, 
                                     dataFourier=totalCmbFourier)

# compute <QE QE>
lCen, Cl, sCl = baseMap.powerSpectrum(dataFourier=QE,
                                             theory=[p2d_cmblens.fPinterp, fNqCmb_fft], 
                                             theory_l = [r'$\langle\kappa\kappa\rangle$', r'$N^{(0)}$'],
                                             plot=True)

# %%
# compute Nhat
sqrtNhat = baseMap.computeQuadEstKappaAutoCorrectionMap(cmb.funlensedTT,
                                                        cmb.fCtotal, 
                                                        lMin=lMin, lMax=lMax, 
                                                        dataFourier=totalCmbFourier)

Nhat_l, Nhat, Nhat_S = baseMap.powerSpectrum(dataFourier=sqrtNhat,
                                             theory=[p2d_cmblens.fPinterp, fNqCmb_fft], 
                                             theory_l = [r'$\langle\kappa\kappa\rangle$', r'$N^{(0)}$'],
                                             plot=True)
# Out:
# /home/users/delon/LensQuEst/LensQuEst/flat_map.py:2579: RuntimeWarning: invalid value encountered in sqrt
#   resultFourier = np.sqrt(np.real(resultFourier))

# %%
# Compute <QE QE> - Nhat
assert(np.allclose(Nhat_l, lCen))
QEQEmNhat = Cl - Nhat
QEQEmNhat_err = np.array([np.sqrt(sCl[i]**2 + Nhat_S[i]**2) for i in range(len(sCl))])

# %%
# Plot the result
fig=plt.figure(0)
ax=fig.add_subplot(111)

ax.errorbar(lCen, QEQEmNhat, yerr=QEQEmNhat_err, c='b', fmt='.', label=r'$\langle\hat\kappa\hat\kappa\rangle - \hat N$')

theory=[p2d_cmblens.fPinterp, fNqCmb_fft]
theory_l = [r'$\langle\kappa\kappa\rangle$', r'$N^{(0)}$']
if(len(theory)>0 and len(theory_l)==0):
    theory_l = ['' for a in range(len(theory))]
    
for f,l in zip(theory, theory_l):
    L = np.logspace(np.log10(1.), np.log10(np.max(baseMap.l.flatten())), 201, 10.)
    ClExpected = np.array(list(map(f, L)))
    ax.plot(L, ClExpected, label=l+' theory')
    
    
    
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$\ell$')
ax.set_ylabel(r'$C_\ell$')
plt.legend(frameon=False)

# %% [markdown]
# This is how it works for a single map. You can do this 500 times for different map realizations and average the results to get a robust estimate for $\langle\kappa\kappa\rangle$. All of our numerical experiments documented in [24XX.XXXXX](https://arxiv.org/abs/24XX.XXXXX) exploring this method can be found in the `dev/` folder.
